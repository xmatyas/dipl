# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# 2024-02-08 22:08:55.634438: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-08 22:08:55.634474: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-08 22:08:55.638223: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-08 22:08:55.652726: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-08 22:08:56.580541: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Num GPUs Available:  1
# 1 Physical GPUs, 1 Logical GPUs
# 2024-02-08 22:08:57.465242: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-08 22:08:57.684421: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-08 22:08:57.684926: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-08 22:08:57.687729: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-08 22:08:57.687955: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-08 22:08:57.688097: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-08 22:08:57.754247: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-08 22:08:57.754416: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-08 22:08:57.754564: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-08 22:08:57.754684: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1197 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Ti, pci bus id: 0000:08:00.0, compute capability: 8.6

# %%
import numpy as np
import pandas as pd
import os
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix

for dirname, _, filenames in os.walk('input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /tmp/ipykernel_24624/3466104978.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
testing_letter = pd.read_csv('../input/emnist-letters-test.csv')
training_letter = pd.read_csv('../input/emnist-letters-train.csv')
class_map = 'ABCDEFGHIJKLMNOPQRSTUVWXYZabdefghnqrt'
print(testing_letter.shape)
print(training_letter.shape)
print(len(class_map))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 testing_letter = pd.read_csv('input/emnist-letters-test.csv')
#       2 training_letter = pd.read_csv('input/emnist-letters-train.csv')
#       3 class_map = 'ABCDEFGHIJKLMNOPQRSTUVWXYZabdefghnqrt'
#
# File ~/Documents/dipl/.venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1024, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1011 kwds_defaults = _refine_defaults_read(
#    1012     dialect,
#    1013     delimiter,
#    (...)
#    1020     dtype_backend=dtype_backend,
#    1021 )
#    1022 kwds.update(kwds_defaults)
# -> 1024 return _read(filepath_or_buffer, kwds)
#
# File ~/Documents/dipl/.venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:618, in _read(filepath_or_buffer, kwds)
#     615 _validate_names(kwds.get("names", None))
#     617 # Create the parser.
# --> 618 parser = TextFileReader(filepath_or_buffer, **kwds)
#     620 if chunksize or iterator:
#     621     return parser
#
# File ~/Documents/dipl/.venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1618, in TextFileReader.__init__(self, f, engine, **kwds)
#    1615     self.options["has_index_names"] = kwds["has_index_names"]
#    1617 self.handles: IOHandles | None = None
# -> 1618 self._engine = self._make_engine(f, self.engine)
#
# File ~/Documents/dipl/.venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1878, in TextFileReader._make_engine(self, f, engine)
#    1876     if "b" not in mode:
#    1877         mode += "b"
# -> 1878 self.handles = get_handle(
#    1879     f,
#    1880     mode,
#    1881     encoding=self.options.get("encoding", None),
#    1882     compression=self.options.get("compression", None),
#    1883     memory_map=self.options.get("memory_map", False),
#    1884     is_text=is_text,
#    1885     errors=self.options.get("encoding_errors", "strict"),
#    1886     storage_options=self.options.get("storage_options", None),
#    1887 )
#    1888 assert self.handles is not None
#    1889 f = self.handles.handle
#
# File ~/Documents/dipl/.venv/lib/python3.11/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'input/emnist-letters-test.csv'

# %%
#training_letters
y1 = np.array(training_letter.iloc[:,0].values)
x1 = np.array(training_letter.iloc[:,1:].values)
#testing_labels
y2 = np.array(testing_letter.iloc[:,0].values)
x2 = np.array(testing_letter.iloc[:,1:].values)
print(y1.shape)
print(x1.shape)
# Out:
# (88799,)
# (88799, 784)

# %%
def show_img(data, row_num):
    img_flip = np.transpose(data.values[row_num,1:].reshape(28, 28), axes=[1,0]) # img_size * img_size arrays
    plt.title('Class: ' + str(data.values[row_num,0]-1) + ', Label: ' + str(class_map[data.values[row_num,0]-1]))
    plt.imshow(img_flip, cmap='Greys_r')

show_img(testing_letter, 1000)

# %%
import tensorflow as tf

# Normalise and reshape data
train_images = x1 / 255.0
test_images = x2 / 255.0

train_images_number = train_images.shape[0]
train_images_height = 28
train_images_width = 28
train_images_size = train_images_height*train_images_width

train_images = train_images.reshape(train_images_number, train_images_height, train_images_width, 1)

test_images_number = test_images.shape[0]
test_images_height = 28
test_images_width = 28
test_images_size = test_images_height*test_images_width

test_images = test_images.reshape(test_images_number, test_images_height, test_images_width, 1)

# %%
# Transform labels
number_of_classes = 37

y1 = tf.keras.utils.to_categorical(y1, number_of_classes)
y2 = tf.keras.utils.to_categorical(y2, number_of_classes)

from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from sklearn.model_selection import train_test_split

train_x,test_x,train_y,test_y = train_test_split(train_images,y1,test_size=0.2,random_state = 42)



model = tf.keras.Sequential([
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(32,3,input_shape=(28,28,1),activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Conv2D(64,3, activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Conv2D(128,3, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),
    #################################################
    tf.keras.layers.Flatten(input_shape=(28,28,1)),
    tf.keras.layers.Dense(256,activation='relu'),
    tf.keras.layers.Dense(128,activation='relu'),
    #tf.keras.layers.Dense(512,activation='relu'),
    #tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(number_of_classes, activation='softmax')
])

model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=tf.keras.metrics.CategoricalAccuracy())

# %%
es = EarlyStopping(monitor='val_categorical_accuracy', mode='max', verbose=1, patience=175)
mc = ModelCheckpoint('advanced2_emnist_model.h5', monitor='val_categorical_accuracy', mode='max', verbose=1, save_best_only=True, patience=175)
history = model.fit(train_x, train_y, batch_size=2048 , epochs=100, validation_split = 0.20 , callbacks=[es,mc])
# Out:
# Epoch 1/100
# 2023-03-28 11:32:49.533895: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential_3/dropout_8/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-03-28 11:32:49.974028: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7fb8506e95f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-03-28 11:32:49.974048: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Ti, Compute Capability 8.6
# 2023-03-28 11:32:50.002481: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-03-28 11:32:50.271778: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 28/28 [==============================] - ETA: 0s - loss: 2.7173 - categorical_accuracy: 0.2726
# Epoch 1: val_categorical_accuracy improved from -inf to 0.04483, saving model to advanced2_emnist_model.h5
# 28/28 [==============================] - 5s 64ms/step - loss: 2.7173 - categorical_accuracy: 0.2726 - val_loss: 3.3973 - val_categorical_accuracy: 0.0448
# Epoch 2/100
# 27/28 [===========================>..] - ETA: 0s - loss: 1.3271 - categorical_accuracy: 0.6059
# Epoch 2: val_categorical_accuracy improved from 0.04483 to 0.04589, saving model to advanced2_emnist_model.h5
# 28/28 [==============================] - 1s 41ms/step - loss: 1.3203 - categorical_accuracy: 0.6076 - val_loss: 5.3914 - val_categorical_accuracy: 0.0459
# Epoch 3/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.8874 - categorical_accuracy: 0.7272
# Epoch 3: val_categorical_accuracy did not improve from 0.04589
# 28/28 [==============================] - 1s 39ms/step - loss: 0.8849 - categorical_accuracy: 0.7278 - val_loss: 7.7520 - val_categorical_accuracy: 0.0395
# Epoch 4/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.6797 - categorical_accuracy: 0.7851
# Epoch 4: val_categorical_accuracy did not improve from 0.04589
# 28/28 [==============================] - 1s 39ms/step - loss: 0.6788 - categorical_accuracy: 0.7855 - val_loss: 9.4075 - val_categorical_accuracy: 0.0384
# Epoch 5/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.5740 - categorical_accuracy: 0.8180
# Epoch 5: val_categorical_accuracy did not improve from 0.04589
# 28/28 [==============================] - 1s 40ms/step - loss: 0.5722 - categorical_accuracy: 0.8185 - val_loss: 10.2260 - val_categorical_accuracy: 0.0434
# Epoch 6/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.5071 - categorical_accuracy: 0.8374
# Epoch 6: val_categorical_accuracy did not improve from 0.04589
# 28/28 [==============================] - 1s 39ms/step - loss: 0.5068 - categorical_accuracy: 0.8378 - val_loss: 10.9947 - val_categorical_accuracy: 0.0383
# Epoch 7/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.4591 - categorical_accuracy: 0.8516
# Epoch 7: val_categorical_accuracy did not improve from 0.04589
# 28/28 [==============================] - 1s 39ms/step - loss: 0.4568 - categorical_accuracy: 0.8523 - val_loss: 10.7734 - val_categorical_accuracy: 0.0383
# Epoch 8/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.4216 - categorical_accuracy: 0.8628
# Epoch 8: val_categorical_accuracy did not improve from 0.04589
# 28/28 [==============================] - 1s 39ms/step - loss: 0.4223 - categorical_accuracy: 0.8626 - val_loss: 10.9349 - val_categorical_accuracy: 0.0409
# Epoch 9/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.3947 - categorical_accuracy: 0.8728
# Epoch 9: val_categorical_accuracy did not improve from 0.04589
# 28/28 [==============================] - 1s 39ms/step - loss: 0.3955 - categorical_accuracy: 0.8727 - val_loss: 9.4377 - val_categorical_accuracy: 0.0441
# Epoch 10/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.3760 - categorical_accuracy: 0.8783
# Epoch 10: val_categorical_accuracy improved from 0.04589 to 0.06053, saving model to advanced2_emnist_model.h5
# 28/28 [==============================] - 1s 45ms/step - loss: 0.3752 - categorical_accuracy: 0.8783 - val_loss: 8.0005 - val_categorical_accuracy: 0.0605
# Epoch 11/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.3562 - categorical_accuracy: 0.8831
# Epoch 11: val_categorical_accuracy improved from 0.06053 to 0.07130, saving model to advanced2_emnist_model.h5
# 28/28 [==============================] - 1s 41ms/step - loss: 0.3570 - categorical_accuracy: 0.8831 - val_loss: 7.7587 - val_categorical_accuracy: 0.0713
# Epoch 12/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.3446 - categorical_accuracy: 0.8873
# Epoch 12: val_categorical_accuracy improved from 0.07130 to 0.15942, saving model to advanced2_emnist_model.h5
# 28/28 [==============================] - 1s 41ms/step - loss: 0.3441 - categorical_accuracy: 0.8877 - val_loss: 5.1642 - val_categorical_accuracy: 0.1594
# Epoch 13/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.3294 - categorical_accuracy: 0.8912
# Epoch 13: val_categorical_accuracy improved from 0.15942 to 0.24261, saving model to advanced2_emnist_model.h5
# 28/28 [==============================] - 1s 40ms/step - loss: 0.3301 - categorical_accuracy: 0.8910 - val_loss: 3.8702 - val_categorical_accuracy: 0.2426
# Epoch 14/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.3212 - categorical_accuracy: 0.8944
# Epoch 14: val_categorical_accuracy improved from 0.24261 to 0.39921, saving model to advanced2_emnist_model.h5
# 28/28 [==============================] - 1s 41ms/step - loss: 0.3207 - categorical_accuracy: 0.8943 - val_loss: 2.4660 - val_categorical_accuracy: 0.3992
# Epoch 15/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.3116 - categorical_accuracy: 0.8966
# Epoch 15: val_categorical_accuracy improved from 0.39921 to 0.60128, saving model to advanced2_emnist_model.h5
# 28/28 [==============================] - 1s 41ms/step - loss: 0.3123 - categorical_accuracy: 0.8965 - val_loss: 1.4103 - val_categorical_accuracy: 0.6013
# Epoch 16/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.3038 - categorical_accuracy: 0.9002
# Epoch 16: val_categorical_accuracy improved from 0.60128 to 0.71889, saving model to advanced2_emnist_model.h5
# 28/28 [==============================] - 1s 41ms/step - loss: 0.3047 - categorical_accuracy: 0.8999 - val_loss: 0.9480 - val_categorical_accuracy: 0.7189
# Epoch 17/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.2952 - categorical_accuracy: 0.9021
# Epoch 17: val_categorical_accuracy improved from 0.71889 to 0.78259, saving model to advanced2_emnist_model.h5
# 28/28 [==============================] - 1s 40ms/step - loss: 0.2959 - categorical_accuracy: 0.9022 - val_loss: 0.7120 - val_categorical_accuracy: 0.7826
# Epoch 18/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.2838 - categorical_accuracy: 0.9056
# Epoch 18: val_categorical_accuracy improved from 0.78259 to 0.83720, saving model to advanced2_emnist_model.h5
# 28/28 [==============================] - 1s 40ms/step - loss: 0.2839 - categorical_accuracy: 0.9056 - val_loss: 0.5301 - val_categorical_accuracy: 0.8372
# Epoch 19/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.2795 - categorical_accuracy: 0.9064
# Epoch 19: val_categorical_accuracy improved from 0.83720 to 0.86705, saving model to advanced2_emnist_model.h5
# 28/28 [==============================] - 1s 41ms/step - loss: 0.2788 - categorical_accuracy: 0.9068 - val_loss: 0.4307 - val_categorical_accuracy: 0.8670
# Epoch 20/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.2760 - categorical_accuracy: 0.9081
# Epoch 20: val_categorical_accuracy improved from 0.86705 to 0.88992, saving model to advanced2_emnist_model.h5
# 28/28 [==============================] - 1s 40ms/step - loss: 0.2764 - categorical_accuracy: 0.9081 - val_loss: 0.3375 - val_categorical_accuracy: 0.8899
# Epoch 21/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.2706 - categorical_accuracy: 0.9084
# Epoch 21: val_categorical_accuracy improved from 0.88992 to 0.90336, saving model to advanced2_emnist_model.h5
# 28/28 [==============================] - 1s 41ms/step - loss: 0.2709 - categorical_accuracy: 0.9083 - val_loss: 0.2848 - val_categorical_accuracy: 0.9034
# Epoch 22/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.2659 - categorical_accuracy: 0.9098
# Epoch 22: val_categorical_accuracy improved from 0.90336 to 0.91610, saving model to advanced2_emnist_model.h5
# 28/28 [==============================] - 1s 41ms/step - loss: 0.2659 - categorical_accuracy: 0.9098 - val_loss: 0.2505 - val_categorical_accuracy: 0.9161
# Epoch 23/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.2624 - categorical_accuracy: 0.9119
# Epoch 23: val_categorical_accuracy improved from 0.91610 to 0.92195, saving model to advanced2_emnist_model.h5
# 28/28 [==============================] - 1s 41ms/step - loss: 0.2618 - categorical_accuracy: 0.9120 - val_loss: 0.2367 - val_categorical_accuracy: 0.9219
# Epoch 24/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.2541 - categorical_accuracy: 0.9132
# Epoch 24: val_categorical_accuracy improved from 0.92195 to 0.92265, saving model to advanced2_emnist_model.h5
# 28/28 [==============================] - 1s 40ms/step - loss: 0.2541 - categorical_accuracy: 0.9133 - val_loss: 0.2324 - val_categorical_accuracy: 0.9226
# Epoch 25/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.2535 - categorical_accuracy: 0.9146
# Epoch 25: val_categorical_accuracy did not improve from 0.92265
# 28/28 [==============================] - 1s 39ms/step - loss: 0.2539 - categorical_accuracy: 0.9146 - val_loss: 0.2442 - val_categorical_accuracy: 0.9167
# Epoch 26/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.2473 - categorical_accuracy: 0.9157
# Epoch 26: val_categorical_accuracy improved from 0.92265 to 0.92511, saving model to advanced2_emnist_model.h5
# 28/28 [==============================] - 1s 44ms/step - loss: 0.2478 - categorical_accuracy: 0.9154 - val_loss: 0.2232 - val_categorical_accuracy: 0.9251
# Epoch 27/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.2453 - categorical_accuracy: 0.9150
# Epoch 27: val_categorical_accuracy improved from 0.92511 to 0.93124, saving model to advanced2_emnist_model.h5
# 28/28 [==============================] - 1s 41ms/step - loss: 0.2466 - categorical_accuracy: 0.9147 - val_loss: 0.2108 - val_categorical_accuracy: 0.9312
# Epoch 28/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.2415 - categorical_accuracy: 0.9168
# Epoch 28: val_categorical_accuracy did not improve from 0.93124
# 28/28 [==============================] - 1s 39ms/step - loss: 0.2420 - categorical_accuracy: 0.9166 - val_loss: 0.2185 - val_categorical_accuracy: 0.9284
# Epoch 29/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.2329 - categorical_accuracy: 0.9192
# Epoch 29: val_categorical_accuracy did not improve from 0.93124
# 28/28 [==============================] - 1s 39ms/step - loss: 0.2334 - categorical_accuracy: 0.9194 - val_loss: 0.2103 - val_categorical_accuracy: 0.9312
# Epoch 30/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.2324 - categorical_accuracy: 0.9209
# Epoch 30: val_categorical_accuracy improved from 0.93124 to 0.93215, saving model to advanced2_emnist_model.h5
# 28/28 [==============================] - 1s 45ms/step - loss: 0.2324 - categorical_accuracy: 0.9208 - val_loss: 0.2077 - val_categorical_accuracy: 0.9322
# Epoch 31/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.2301 - categorical_accuracy: 0.9214
# Epoch 31: val_categorical_accuracy improved from 0.93215 to 0.93222, saving model to advanced2_emnist_model.h5
# 28/28 [==============================] - 1s 41ms/step - loss: 0.2305 - categorical_accuracy: 0.9215 - val_loss: 0.2084 - val_categorical_accuracy: 0.9322
# Epoch 32/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.2309 - categorical_accuracy: 0.9198
# Epoch 32: val_categorical_accuracy did not improve from 0.93222
# 28/28 [==============================] - 1s 39ms/step - loss: 0.2312 - categorical_accuracy: 0.9200 - val_loss: 0.2076 - val_categorical_accuracy: 0.9320
# Epoch 33/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.2279 - categorical_accuracy: 0.9215
# Epoch 33: val_categorical_accuracy improved from 0.93222 to 0.93377, saving model to advanced2_emnist_model.h5
# 28/28 [==============================] - 1s 45ms/step - loss: 0.2279 - categorical_accuracy: 0.9217 - val_loss: 0.2019 - val_categorical_accuracy: 0.9338
# Epoch 34/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.2249 - categorical_accuracy: 0.9214
# Epoch 34: val_categorical_accuracy improved from 0.93377 to 0.93384, saving model to advanced2_emnist_model.h5
# 28/28 [==============================] - 1s 41ms/step - loss: 0.2246 - categorical_accuracy: 0.9216 - val_loss: 0.2000 - val_categorical_accuracy: 0.9338
# Epoch 35/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.2187 - categorical_accuracy: 0.9232
# Epoch 35: val_categorical_accuracy improved from 0.93384 to 0.93637, saving model to advanced2_emnist_model.h5
# 28/28 [==============================] - 1s 40ms/step - loss: 0.2184 - categorical_accuracy: 0.9232 - val_loss: 0.1959 - val_categorical_accuracy: 0.9364
# Epoch 36/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.2182 - categorical_accuracy: 0.9240
# Epoch 36: val_categorical_accuracy did not improve from 0.93637
# 28/28 [==============================] - 1s 39ms/step - loss: 0.2178 - categorical_accuracy: 0.9241 - val_loss: 0.2114 - val_categorical_accuracy: 0.9311
# Epoch 37/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.2160 - categorical_accuracy: 0.9244
# Epoch 37: val_categorical_accuracy improved from 0.93637 to 0.93644, saving model to advanced2_emnist_model.h5
# 28/28 [==============================] - 1s 41ms/step - loss: 0.2163 - categorical_accuracy: 0.9242 - val_loss: 0.1906 - val_categorical_accuracy: 0.9364
# Epoch 38/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.2146 - categorical_accuracy: 0.9245
# Epoch 38: val_categorical_accuracy did not improve from 0.93644
# 28/28 [==============================] - 1s 39ms/step - loss: 0.2156 - categorical_accuracy: 0.9242 - val_loss: 0.1920 - val_categorical_accuracy: 0.9360
# Epoch 39/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.2086 - categorical_accuracy: 0.9253
# Epoch 39: val_categorical_accuracy did not improve from 0.93644
# 28/28 [==============================] - 1s 39ms/step - loss: 0.2081 - categorical_accuracy: 0.9255 - val_loss: 0.1920 - val_categorical_accuracy: 0.9364
# Epoch 40/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.2106 - categorical_accuracy: 0.9258
# Epoch 40: val_categorical_accuracy improved from 0.93644 to 0.93736, saving model to advanced2_emnist_model.h5
# 28/28 [==============================] - 1s 40ms/step - loss: 0.2109 - categorical_accuracy: 0.9257 - val_loss: 0.1885 - val_categorical_accuracy: 0.9374
# Epoch 41/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.2100 - categorical_accuracy: 0.9256
# Epoch 41: val_categorical_accuracy did not improve from 0.93736
# 28/28 [==============================] - 1s 39ms/step - loss: 0.2098 - categorical_accuracy: 0.9256 - val_loss: 0.1915 - val_categorical_accuracy: 0.9362
# Epoch 42/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.2087 - categorical_accuracy: 0.9269
# Epoch 42: val_categorical_accuracy did not improve from 0.93736
# 28/28 [==============================] - 1s 39ms/step - loss: 0.2084 - categorical_accuracy: 0.9271 - val_loss: 0.1902 - val_categorical_accuracy: 0.9371
# Epoch 43/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.2044 - categorical_accuracy: 0.9289
# Epoch 43: val_categorical_accuracy did not improve from 0.93736
# 28/28 [==============================] - 1s 38ms/step - loss: 0.2039 - categorical_accuracy: 0.9289 - val_loss: 0.1956 - val_categorical_accuracy: 0.9369
# Epoch 44/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.2038 - categorical_accuracy: 0.9273
# Epoch 44: val_categorical_accuracy improved from 0.93736 to 0.93968, saving model to advanced2_emnist_model.h5
# 28/28 [==============================] - 1s 43ms/step - loss: 0.2033 - categorical_accuracy: 0.9275 - val_loss: 0.1831 - val_categorical_accuracy: 0.9397
# Epoch 45/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.2040 - categorical_accuracy: 0.9280
# Epoch 45: val_categorical_accuracy did not improve from 0.93968
# 28/28 [==============================] - 1s 39ms/step - loss: 0.2042 - categorical_accuracy: 0.9277 - val_loss: 0.1889 - val_categorical_accuracy: 0.9376
# Epoch 46/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.2010 - categorical_accuracy: 0.9290
# Epoch 46: val_categorical_accuracy did not improve from 0.93968
# 28/28 [==============================] - 1s 39ms/step - loss: 0.2004 - categorical_accuracy: 0.9292 - val_loss: 0.1877 - val_categorical_accuracy: 0.9382
# Epoch 47/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1948 - categorical_accuracy: 0.9299
# Epoch 47: val_categorical_accuracy improved from 0.93968 to 0.93982, saving model to advanced2_emnist_model.h5
# 28/28 [==============================] - 1s 45ms/step - loss: 0.1959 - categorical_accuracy: 0.9297 - val_loss: 0.1850 - val_categorical_accuracy: 0.9398
# Epoch 48/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1968 - categorical_accuracy: 0.9296
# Epoch 48: val_categorical_accuracy did not improve from 0.93982
# 28/28 [==============================] - 1s 39ms/step - loss: 0.1970 - categorical_accuracy: 0.9295 - val_loss: 0.1855 - val_categorical_accuracy: 0.9386
# Epoch 49/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1953 - categorical_accuracy: 0.9300
# Epoch 49: val_categorical_accuracy did not improve from 0.93982
# 28/28 [==============================] - 1s 39ms/step - loss: 0.1955 - categorical_accuracy: 0.9299 - val_loss: 0.1846 - val_categorical_accuracy: 0.9397
# Epoch 50/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1926 - categorical_accuracy: 0.9320
# Epoch 50: val_categorical_accuracy improved from 0.93982 to 0.94116, saving model to advanced2_emnist_model.h5
# 28/28 [==============================] - 1s 41ms/step - loss: 0.1921 - categorical_accuracy: 0.9321 - val_loss: 0.1823 - val_categorical_accuracy: 0.9412
# Epoch 51/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1901 - categorical_accuracy: 0.9314
# Epoch 51: val_categorical_accuracy did not improve from 0.94116
# 28/28 [==============================] - 1s 39ms/step - loss: 0.1901 - categorical_accuracy: 0.9316 - val_loss: 0.1894 - val_categorical_accuracy: 0.9374
# Epoch 52/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1902 - categorical_accuracy: 0.9322
# Epoch 52: val_categorical_accuracy did not improve from 0.94116
# 28/28 [==============================] - 1s 39ms/step - loss: 0.1905 - categorical_accuracy: 0.9321 - val_loss: 0.1899 - val_categorical_accuracy: 0.9398
# Epoch 53/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1868 - categorical_accuracy: 0.9311
# Epoch 53: val_categorical_accuracy did not improve from 0.94116
# 28/28 [==============================] - 1s 39ms/step - loss: 0.1863 - categorical_accuracy: 0.9311 - val_loss: 0.1869 - val_categorical_accuracy: 0.9406
# Epoch 54/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1859 - categorical_accuracy: 0.9339
# Epoch 54: val_categorical_accuracy did not improve from 0.94116
# 28/28 [==============================] - 1s 39ms/step - loss: 0.1857 - categorical_accuracy: 0.9340 - val_loss: 0.1880 - val_categorical_accuracy: 0.9400
# Epoch 55/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1812 - categorical_accuracy: 0.9348
# Epoch 55: val_categorical_accuracy did not improve from 0.94116
# 28/28 [==============================] - 1s 39ms/step - loss: 0.1826 - categorical_accuracy: 0.9346 - val_loss: 0.1946 - val_categorical_accuracy: 0.9349
# Epoch 56/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1877 - categorical_accuracy: 0.9327
# Epoch 56: val_categorical_accuracy did not improve from 0.94116
# 28/28 [==============================] - 1s 39ms/step - loss: 0.1872 - categorical_accuracy: 0.9327 - val_loss: 0.1860 - val_categorical_accuracy: 0.9405
# Epoch 57/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1817 - categorical_accuracy: 0.9351
# Epoch 57: val_categorical_accuracy did not improve from 0.94116
# 28/28 [==============================] - 1s 39ms/step - loss: 0.1824 - categorical_accuracy: 0.9350 - val_loss: 0.1946 - val_categorical_accuracy: 0.9388
# Epoch 58/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1808 - categorical_accuracy: 0.9344
# Epoch 58: val_categorical_accuracy did not improve from 0.94116
# 28/28 [==============================] - 1s 39ms/step - loss: 0.1805 - categorical_accuracy: 0.9345 - val_loss: 0.1828 - val_categorical_accuracy: 0.9405
# Epoch 59/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1824 - categorical_accuracy: 0.9344
# Epoch 59: val_categorical_accuracy did not improve from 0.94116
# 28/28 [==============================] - 1s 39ms/step - loss: 0.1826 - categorical_accuracy: 0.9343 - val_loss: 0.1843 - val_categorical_accuracy: 0.9403
# Epoch 60/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1773 - categorical_accuracy: 0.9349
# Epoch 60: val_categorical_accuracy did not improve from 0.94116
# 28/28 [==============================] - 1s 39ms/step - loss: 0.1776 - categorical_accuracy: 0.9348 - val_loss: 0.1845 - val_categorical_accuracy: 0.9396
# Epoch 61/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1767 - categorical_accuracy: 0.9361
# Epoch 61: val_categorical_accuracy did not improve from 0.94116
# 28/28 [==============================] - 1s 40ms/step - loss: 0.1761 - categorical_accuracy: 0.9362 - val_loss: 0.1813 - val_categorical_accuracy: 0.9411
# Epoch 62/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1756 - categorical_accuracy: 0.9362
# Epoch 62: val_categorical_accuracy did not improve from 0.94116
# 28/28 [==============================] - 1s 39ms/step - loss: 0.1763 - categorical_accuracy: 0.9359 - val_loss: 0.1919 - val_categorical_accuracy: 0.9385
# Epoch 63/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1765 - categorical_accuracy: 0.9358
# Epoch 63: val_categorical_accuracy did not improve from 0.94116
# 28/28 [==============================] - 1s 39ms/step - loss: 0.1767 - categorical_accuracy: 0.9358 - val_loss: 0.1807 - val_categorical_accuracy: 0.9412
# Epoch 64/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1731 - categorical_accuracy: 0.9369
# Epoch 64: val_categorical_accuracy did not improve from 0.94116
# 28/28 [==============================] - 1s 39ms/step - loss: 0.1739 - categorical_accuracy: 0.9367 - val_loss: 0.1884 - val_categorical_accuracy: 0.9398
# Epoch 65/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1734 - categorical_accuracy: 0.9366
# Epoch 65: val_categorical_accuracy improved from 0.94116 to 0.94236, saving model to advanced2_emnist_model.h5
# 28/28 [==============================] - 1s 41ms/step - loss: 0.1742 - categorical_accuracy: 0.9364 - val_loss: 0.1790 - val_categorical_accuracy: 0.9424
# Epoch 66/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1716 - categorical_accuracy: 0.9372
# Epoch 66: val_categorical_accuracy did not improve from 0.94236
# 28/28 [==============================] - 1s 39ms/step - loss: 0.1721 - categorical_accuracy: 0.9371 - val_loss: 0.1864 - val_categorical_accuracy: 0.9401
# Epoch 67/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1702 - categorical_accuracy: 0.9384
# Epoch 67: val_categorical_accuracy did not improve from 0.94236
# 28/28 [==============================] - 1s 39ms/step - loss: 0.1701 - categorical_accuracy: 0.9386 - val_loss: 0.1812 - val_categorical_accuracy: 0.9411
# Epoch 68/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1660 - categorical_accuracy: 0.9389
# Epoch 68: val_categorical_accuracy did not improve from 0.94236
# 28/28 [==============================] - 1s 39ms/step - loss: 0.1658 - categorical_accuracy: 0.9388 - val_loss: 0.1798 - val_categorical_accuracy: 0.9422
# Epoch 69/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1697 - categorical_accuracy: 0.9386
# Epoch 69: val_categorical_accuracy did not improve from 0.94236
# 28/28 [==============================] - 1s 39ms/step - loss: 0.1701 - categorical_accuracy: 0.9384 - val_loss: 0.1858 - val_categorical_accuracy: 0.9417
# Epoch 70/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1680 - categorical_accuracy: 0.9391
# Epoch 70: val_categorical_accuracy did not improve from 0.94236
# 28/28 [==============================] - 1s 39ms/step - loss: 0.1685 - categorical_accuracy: 0.9389 - val_loss: 0.1906 - val_categorical_accuracy: 0.9391
# Epoch 71/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1681 - categorical_accuracy: 0.9382
# Epoch 71: val_categorical_accuracy did not improve from 0.94236
# 28/28 [==============================] - 1s 39ms/step - loss: 0.1681 - categorical_accuracy: 0.9382 - val_loss: 0.1853 - val_categorical_accuracy: 0.9406
# Epoch 72/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1694 - categorical_accuracy: 0.9382
# Epoch 72: val_categorical_accuracy did not improve from 0.94236
# 28/28 [==============================] - 1s 39ms/step - loss: 0.1694 - categorical_accuracy: 0.9383 - val_loss: 0.1791 - val_categorical_accuracy: 0.9424
# Epoch 73/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1669 - categorical_accuracy: 0.9379
# Epoch 73: val_categorical_accuracy did not improve from 0.94236
# 28/28 [==============================] - 1s 40ms/step - loss: 0.1671 - categorical_accuracy: 0.9377 - val_loss: 0.1898 - val_categorical_accuracy: 0.9406
# Epoch 74/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1687 - categorical_accuracy: 0.9367
# Epoch 74: val_categorical_accuracy improved from 0.94236 to 0.94278, saving model to advanced2_emnist_model.h5
# 28/28 [==============================] - 1s 41ms/step - loss: 0.1679 - categorical_accuracy: 0.9371 - val_loss: 0.1783 - val_categorical_accuracy: 0.9428
# Epoch 75/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1650 - categorical_accuracy: 0.9388
# Epoch 75: val_categorical_accuracy did not improve from 0.94278
# 28/28 [==============================] - 1s 39ms/step - loss: 0.1649 - categorical_accuracy: 0.9389 - val_loss: 0.1867 - val_categorical_accuracy: 0.9411
# Epoch 76/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1638 - categorical_accuracy: 0.9392
# Epoch 76: val_categorical_accuracy did not improve from 0.94278
# 28/28 [==============================] - 1s 39ms/step - loss: 0.1638 - categorical_accuracy: 0.9393 - val_loss: 0.1851 - val_categorical_accuracy: 0.9418
# Epoch 77/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1634 - categorical_accuracy: 0.9395
# Epoch 77: val_categorical_accuracy did not improve from 0.94278
# 28/28 [==============================] - 1s 39ms/step - loss: 0.1636 - categorical_accuracy: 0.9394 - val_loss: 0.1844 - val_categorical_accuracy: 0.9424
# Epoch 78/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1601 - categorical_accuracy: 0.9402
# Epoch 78: val_categorical_accuracy did not improve from 0.94278
# 28/28 [==============================] - 1s 39ms/step - loss: 0.1597 - categorical_accuracy: 0.9405 - val_loss: 0.1827 - val_categorical_accuracy: 0.9426
# Epoch 79/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1597 - categorical_accuracy: 0.9415
# Epoch 79: val_categorical_accuracy did not improve from 0.94278
# 28/28 [==============================] - 1s 39ms/step - loss: 0.1600 - categorical_accuracy: 0.9413 - val_loss: 0.1921 - val_categorical_accuracy: 0.9398
# Epoch 80/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1610 - categorical_accuracy: 0.9399
# Epoch 80: val_categorical_accuracy improved from 0.94278 to 0.94390, saving model to advanced2_emnist_model.h5
# 28/28 [==============================] - 1s 44ms/step - loss: 0.1609 - categorical_accuracy: 0.9399 - val_loss: 0.1803 - val_categorical_accuracy: 0.9439
# Epoch 81/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1611 - categorical_accuracy: 0.9400
# Epoch 81: val_categorical_accuracy did not improve from 0.94390
# 28/28 [==============================] - 1s 39ms/step - loss: 0.1598 - categorical_accuracy: 0.9406 - val_loss: 0.1827 - val_categorical_accuracy: 0.9431
# Epoch 82/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1555 - categorical_accuracy: 0.9410
# Epoch 82: val_categorical_accuracy did not improve from 0.94390
# 28/28 [==============================] - 1s 40ms/step - loss: 0.1556 - categorical_accuracy: 0.9409 - val_loss: 0.1847 - val_categorical_accuracy: 0.9437
# Epoch 83/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1602 - categorical_accuracy: 0.9408
# Epoch 83: val_categorical_accuracy did not improve from 0.94390
# 28/28 [==============================] - 1s 40ms/step - loss: 0.1601 - categorical_accuracy: 0.9409 - val_loss: 0.1861 - val_categorical_accuracy: 0.9423
# Epoch 84/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1593 - categorical_accuracy: 0.9407
# Epoch 84: val_categorical_accuracy did not improve from 0.94390
# 28/28 [==============================] - 1s 39ms/step - loss: 0.1594 - categorical_accuracy: 0.9408 - val_loss: 0.1813 - val_categorical_accuracy: 0.9438
# Epoch 85/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1580 - categorical_accuracy: 0.9410
# Epoch 85: val_categorical_accuracy did not improve from 0.94390
# 28/28 [==============================] - 1s 40ms/step - loss: 0.1581 - categorical_accuracy: 0.9410 - val_loss: 0.1863 - val_categorical_accuracy: 0.9424
# Epoch 86/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1568 - categorical_accuracy: 0.9421
# Epoch 86: val_categorical_accuracy did not improve from 0.94390
# 28/28 [==============================] - 1s 40ms/step - loss: 0.1570 - categorical_accuracy: 0.9420 - val_loss: 0.1827 - val_categorical_accuracy: 0.9428
# Epoch 87/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1557 - categorical_accuracy: 0.9416
# Epoch 87: val_categorical_accuracy did not improve from 0.94390
# 28/28 [==============================] - 1s 39ms/step - loss: 0.1554 - categorical_accuracy: 0.9415 - val_loss: 0.1800 - val_categorical_accuracy: 0.9438
# Epoch 88/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1561 - categorical_accuracy: 0.9410
# Epoch 88: val_categorical_accuracy improved from 0.94390 to 0.94447, saving model to advanced2_emnist_model.h5
# 28/28 [==============================] - 1s 41ms/step - loss: 0.1559 - categorical_accuracy: 0.9412 - val_loss: 0.1774 - val_categorical_accuracy: 0.9445
# Epoch 89/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1521 - categorical_accuracy: 0.9429
# Epoch 89: val_categorical_accuracy did not improve from 0.94447
# 28/28 [==============================] - 1s 39ms/step - loss: 0.1520 - categorical_accuracy: 0.9429 - val_loss: 0.1867 - val_categorical_accuracy: 0.9438
# Epoch 90/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1535 - categorical_accuracy: 0.9425
# Epoch 90: val_categorical_accuracy did not improve from 0.94447
# 28/28 [==============================] - 1s 39ms/step - loss: 0.1535 - categorical_accuracy: 0.9424 - val_loss: 0.1851 - val_categorical_accuracy: 0.9431
# Epoch 91/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1566 - categorical_accuracy: 0.9413
# Epoch 91: val_categorical_accuracy did not improve from 0.94447
# 28/28 [==============================] - 1s 39ms/step - loss: 0.1561 - categorical_accuracy: 0.9415 - val_loss: 0.1799 - val_categorical_accuracy: 0.9429
# Epoch 92/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1534 - categorical_accuracy: 0.9416
# Epoch 92: val_categorical_accuracy improved from 0.94447 to 0.94468, saving model to advanced2_emnist_model.h5
# 28/28 [==============================] - 1s 45ms/step - loss: 0.1539 - categorical_accuracy: 0.9415 - val_loss: 0.1800 - val_categorical_accuracy: 0.9447
# Epoch 93/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1513 - categorical_accuracy: 0.9436
# Epoch 93: val_categorical_accuracy did not improve from 0.94468
# 28/28 [==============================] - 1s 39ms/step - loss: 0.1513 - categorical_accuracy: 0.9436 - val_loss: 0.1856 - val_categorical_accuracy: 0.9417
# Epoch 94/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1508 - categorical_accuracy: 0.9434
# Epoch 94: val_categorical_accuracy did not improve from 0.94468
# 28/28 [==============================] - 1s 39ms/step - loss: 0.1508 - categorical_accuracy: 0.9433 - val_loss: 0.1804 - val_categorical_accuracy: 0.9434
# Epoch 95/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1492 - categorical_accuracy: 0.9442
# Epoch 95: val_categorical_accuracy did not improve from 0.94468
# 28/28 [==============================] - 1s 39ms/step - loss: 0.1493 - categorical_accuracy: 0.9440 - val_loss: 0.1813 - val_categorical_accuracy: 0.9434
# Epoch 96/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1497 - categorical_accuracy: 0.9434
# Epoch 96: val_categorical_accuracy did not improve from 0.94468
# 28/28 [==============================] - 1s 39ms/step - loss: 0.1499 - categorical_accuracy: 0.9433 - val_loss: 0.1893 - val_categorical_accuracy: 0.9416
# Epoch 97/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1509 - categorical_accuracy: 0.9431
# Epoch 97: val_categorical_accuracy did not improve from 0.94468
# 28/28 [==============================] - 1s 39ms/step - loss: 0.1510 - categorical_accuracy: 0.9433 - val_loss: 0.1854 - val_categorical_accuracy: 0.9426
# Epoch 98/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1519 - categorical_accuracy: 0.9433
# Epoch 98: val_categorical_accuracy did not improve from 0.94468
# 28/28 [==============================] - 1s 39ms/step - loss: 0.1517 - categorical_accuracy: 0.9434 - val_loss: 0.1881 - val_categorical_accuracy: 0.9425
# Epoch 99/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1532 - categorical_accuracy: 0.9431
# Epoch 99: val_categorical_accuracy did not improve from 0.94468
# 28/28 [==============================] - 1s 39ms/step - loss: 0.1532 - categorical_accuracy: 0.9429 - val_loss: 0.1864 - val_categorical_accuracy: 0.9428
# Epoch 100/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.1479 - categorical_accuracy: 0.9446
# Epoch 100: val_categorical_accuracy did not improve from 0.94468
# 28/28 [==============================] - 1s 40ms/step - loss: 0.1479 - categorical_accuracy: 0.9445 - val_loss: 0.1829 - val_categorical_accuracy: 0.9433

# %%
from tensorflow.keras.models import load_model

model = load_model('advanced_emnist_model.h5')
model.evaluate(test_x, test_y, verbose=2)

probability_model = tf.keras.Sequential([
  model,
  tf.keras.layers.Softmax()
])
probability_model(test_x[:5])
# Out:
# 555/555 - 1s - loss: 0.1752 - categorical_accuracy: 0.9459 - 979ms/epoch - 2ms/step
# <tf.Tensor: shape=(5, 37), dtype=float32, numpy=
# array([[0.02600241, 0.05867292, 0.02600242, 0.02600241, 0.02600242,
#         0.02600242, 0.02600241, 0.03079814, 0.02600241, 0.02600241,
#         0.02600241, 0.02600241, 0.02600241, 0.02600241, 0.02600242,
#         0.02600241, 0.02600241, 0.02644672, 0.02600241, 0.02600241,
#         0.02600241, 0.02600249, 0.02600241, 0.02600241, 0.02600241,
#         0.02600241, 0.02600241, 0.02600241, 0.02600241, 0.02600241,
#         0.02600241, 0.02600241, 0.02600241, 0.02600241, 0.02600241,
#         0.02600241, 0.02600241],
#        [0.02608874, 0.02608874, 0.02608902, 0.02608874, 0.03696177,
#         0.02608874, 0.02608874, 0.02608874, 0.02608874, 0.02608874,
#         0.02609049, 0.02608874, 0.02608874, 0.02608874, 0.02608874,
#         0.02608907, 0.02608883, 0.02608874, 0.02608874, 0.02608874,
#         0.02608874, 0.04979796, 0.02621984, 0.02608944, 0.02608874,
#         0.02608911, 0.02608874, 0.02608874, 0.02608874, 0.02608874,
#         0.02608874, 0.02608874, 0.02608874, 0.02608874, 0.02608874,
#         0.02608874, 0.02608874],
#        [0.0258289 , 0.0258289 , 0.0258289 , 0.0258289 , 0.02582891,
#         0.02582891, 0.0258289 , 0.02582891, 0.0258289 , 0.02582891,
#         0.0258289 , 0.02582926, 0.02582891, 0.0258289 , 0.02582891,
#         0.0258289 , 0.0258289 , 0.0258289 , 0.02582891, 0.0258289 ,
#         0.0258289 , 0.0258289 , 0.02582893, 0.0258289 , 0.07012985,
#         0.02585805, 0.02582895, 0.0258289 , 0.0258289 , 0.0258289 ,
#         0.0258289 , 0.0258289 , 0.0258289 , 0.0258289 , 0.0258289 ,
#         0.0258289 , 0.0258289 ],
#        [0.0258331 , 0.0258331 , 0.02583311, 0.0258331 , 0.025958  ,
#         0.0258331 , 0.0258331 , 0.0258331 , 0.0258331 , 0.0258331 ,
#         0.0258331 , 0.0258331 , 0.0258331 , 0.0258331 , 0.0258331 ,
#         0.06988361, 0.0258331 , 0.02583312, 0.0258331 , 0.0258331 ,
#         0.0258331 , 0.0258331 , 0.0258331 , 0.0258331 , 0.0258331 ,
#         0.0258331 , 0.0258331 , 0.0258331 , 0.0258331 , 0.0258331 ,
#         0.0258331 , 0.0258331 , 0.0258331 , 0.0258331 , 0.0258331 ,
#         0.0258331 , 0.0258331 ],
#        [0.02582759, 0.02582759, 0.02582759, 0.02582759, 0.02582759,
#         0.02582759, 0.02582759, 0.02582759, 0.02582759, 0.02582759,
#         0.02582759, 0.02582759, 0.02582759, 0.02582759, 0.02582759,
#         0.02582759, 0.02582759, 0.02582759, 0.02582759, 0.02582759,
#         0.02582759, 0.02582759, 0.02582759, 0.07020666, 0.02582759,
#         0.02582759, 0.02582759, 0.02582759, 0.02582759, 0.02582759,
#         0.02582759, 0.02582759, 0.02582759, 0.02582759, 0.02582759,
#         0.02582759, 0.02582759]], dtype=float32)>

# %%
conf_mat = confusion_matrix(y_true = np.argmax(test_y, axis=1), y_pred = np.argmax(model.predict(test_x), axis=1))
plt.imshow(conf_mat, cmap = 'gray', vmin = 0, vmax = 255)
plt.show()

import ipympl
# %matplotlib widget
# Out:
# 555/555 [==============================] - 1s 1ms/step
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import random

def show_predicted_images(images, title_texts, predicted_labels):
    cols = 5
    rows = int(len(images)/cols) + 1
    plt.figure(figsize=(30,20))
    index = 1
    for x in zip(images, title_texts, predicted_labels):
        image = x[0]        
        title_text = np.argmax(x[1])
        predicted_label = x[2]
        plt.subplot(rows, cols, index)
        image_flip = np.transpose(image.reshape(28, 28), axes=[1,0]) # img_size * img_size arrays    
        plt.imshow(image_flip, cmap='Greys_r')
        if (title_text != ''):
            if (title_text == predicted_label):
                plt.title("Label : " + str(class_map[title_text-1]) + "  Predicted : " + str(class_map[predicted_label-1]), fontsize = 15);
            else:
                plt.title("Label : " + str(class_map[title_text-1]) + "  Predicted : " + str(class_map[predicted_label-1]), fontsize = 15, color = 'red');
        index += 1

random_image_index = []
for i in range(0, 20):
    r = random.randint(1, len(test_x))
    random_image_index.append(r)
if len(random_image_index) > 0:
    random_x_val = np.array([test_x[index] for index in random_image_index])
    random_y_val = np.array([test_y[index] for index in random_image_index])

predicted_labels = model.predict(random_x_val)
predicted_labels = np.argmax(predicted_labels, 1)
show_predicted_images(random_x_val,random_y_val,predicted_labels)
# Out:
# 1/1 [==============================] - 0s 96ms/step

# %%
import random

def show_wrongly_predicted_images(images, title_labels, predicted_labels, r_num):
    wrong_predictions = []
    for x in zip(images, title_labels, predicted_labels):
        image = x[0]
        title_label = np.argmax(x[1])
        predicted_label = x[2]
        #check for null title texts
        if(title_label != ''):
            #check if predicted labels mismatch
            if (title_label != predicted_label):
                wrong_predictions.append(x)
    print("WRONG_PREDICTIONS : {}".format(len(wrong_predictions)))
    if (len(wrong_predictions) > r_num):
        wrong_predictions_sample = random.sample(wrong_predictions, k=r_num)
        index = 1
        cols = 5
        rows = int(r_num/cols) + 1
        plt.figure(figsize=(20,20))
        for w_prediction in wrong_predictions_sample:
            image = w_prediction[0]
            plt.subplot(rows, cols, index)
            plt.tick_params(left=False, bottom=False)
            ax = plt.gca()
            ax.axes.xaxis.set_visible(False)
            ax.axes.yaxis.set_visible(False)
            image_flip = np.transpose(image.reshape(28, 28), axes=[1,0]) # img_size * img_size arrays    
            plt.imshow(image_flip, cmap='Greys_r')
            plt.title("Label : " + str(class_map[np.argmax(w_prediction[1])-1]) + "  Predicted : " + str(class_map[w_prediction[2]-1]), fontsize = 15, color = 'red');
            index += 1
    else:
        raise ValueError('Not enough wrong predictions! Predictions {} > Num {}'.format(len(wrong_predictions), number))
        
            
predicted_labels = model.predict(test_x)
predicted_labels = np.argmax(predicted_labels, 1)
show_wrongly_predicted_images(test_x,test_y,predicted_labels, 30)
# Out:
# 555/555 [==============================] - 1s 909us/step
# WRONG_PREDICTIONS : 962

# %%
import cv2
from matplotlib import pyplot as plt

image = cv2.imread('G.png')
grayImage = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
(thresh, blackAndWhiteImage) = cv2.threshold(grayImage, 192, 255, cv2.THRESH_BINARY)
blackAndWhiteImage = cv2.bitwise_not(blackAndWhiteImage)
output = cv2.resize(blackAndWhiteImage, (28, 28), interpolation = cv2.INTER_AREA)

output = np.array(output)
print(output.shape)
# Out:
# (28, 28)
